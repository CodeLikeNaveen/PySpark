# %%
# Data Import
df = spark.read.format('csv').option('inferSchema', True).option('header', True).load('/Workspace/Users/naveenreddu89@gmail.com/DataBricks_Naveen/BigMart_Sales.csv')

# %%
# display(df)
df.printSchema()

# %% [markdown]
# ## Why do we want it
# - when we want to infer the schema of data by manual way

# %% [markdown]
# ### **DDL Schema**

# %%
ddl  = '''
    Item_Identifier STRING,
    Item_Weight STRING,
    Item_Fat_Content STRING,
    Item_Visibility DOUBLE,
    Item_Type STRING,
    Item_MRP DOUBLE,
    Outlet_Identifier STRING,
    Outlet_Establishment_Year INT,
    Outlet_Size STRING,
    Outlet_Location_Type STRING,
    Outlet_Type STRING,
    Item_Outlet_Sales DOUBLE
'''
## chaged Item_Weight DOUBLE to STRING

# %%
df = spark.read.format('csv')\
    .schema(ddl)\
    .option('header', True)\
    .load('file:/Workspace/Users/naveenreddu89@gmail.com/DataBricks_Naveen/BigMart_Sales.csv')

# %%
df.printSchema()
# display(df)

# %% [markdown]
# ### **StructType Schema**

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
my_struct_schema = StructType([
    StructField('Item_Identifier', StringType(), True),  # True for allow null or not
    StructField('Item_Weight', StringType(), True),
    StructField('Item_Fat_Content', StringType(), True),
    StructField('Item_Visibility', DoubleType(), True),
    StructField('Item_Type', StringType(), True),
    StructField('Item_MRP', DoubleType(), True),
    StructField('Outlet_Identifier', StringType(), True),
    StructField('Outlet_Establishment_Year', IntegerType(), True),
    StructField('Outlet_Size', StringType(), True),
    StructField('Outlet_Location_Type', StringType(), True),
    StructField('Outlet_Type', StringType(), True),
    StructField('Item_Outlet_Sales', DoubleType(), True)
])

# %%
df = spark.read.format('csv')\
        .schema(my_struct_schema)\
        .option('header', True)\
        .load('file:/Workspace/Users/naveenreddu89@gmail.com/DataBricks_Naveen/BigMart_Sales.csv')

# %%
df.printSchema()
