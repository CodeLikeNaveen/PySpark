# %%
# get the path of file
# dbutils.fs.ls('/Workspace/Users/naveenreddu89@gmail.com/DataBricks_Naveen')

# %% [markdown]
# ## **First Data Read From CSV File**

# %%
df = spark.read.format('csv').option('inferSchema', True).option('header', True).load('/Workspace/Users/naveenreddu89@gmail.com/DataBricks_Naveen/BigMart_Sales.csv')
# print(df.head())

# %%
# df.show() # show data but format is not good
df.display() # show data in a good format

# %% [markdown]
# ## **JSON Data Upload**

# %%
df_json = spark.read.format('json')\
    .option('inferSchema', True)\
    .option('header', True)\
    .option('multLine', False)\
    .load('/Volumes/workspace/default/data/test_data/drivers.json')

# %%
# df_json.display() # old way and behind alias of below code
display(df_json)
