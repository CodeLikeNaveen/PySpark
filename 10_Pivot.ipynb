# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *
ddl  = '''
    Item_Identifier STRING,
    Item_Weight DOUBLE,
    Item_Fat_Content STRING,
    Item_Visibility DOUBLE,
    Item_Type STRING,
    Item_MRP DOUBLE,
    Outlet_Identifier STRING,
    Outlet_Establishment_Year INT,
    Outlet_Size STRING,
    Outlet_Location_Type STRING,
    Outlet_Type STRING,
    Item_Outlet_Sales DOUBLE
'''
df = spark.read.format('csv')\
    .schema(ddl)\
    .option('header', True)\
    .load('file:/Workspace/Users/naveenreddu89@gmail.com/DataBricks_Naveen/BigMart_Sales.csv')

# %% [markdown]
# #### **Data**

# %%
display(df.groupBy('Item_Type','Outlet_Size').agg(sum('Item_MRP').alias("Total_MRP")))

# %% [markdown]
# ### **Pivot**

# %%
# Item_Type     -> Rows
# Outlet_Size   -> Columns
display(df.groupBy('Item_Type').pivot('Outlet_Size').agg(avg('Item_MRP')))
