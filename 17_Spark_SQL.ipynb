# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *
ddl  = '''
    Item_Identifier STRING,
    Item_Weight DOUBLE,
    Item_Fat_Content STRING,
    Item_Visibility DOUBLE,
    Item_Type STRING,
    Item_MRP DOUBLE,
    Outlet_Identifier STRING,
    Outlet_Establishment_Year INT,
    Outlet_Size STRING,
    Outlet_Location_Type STRING,
    Outlet_Type STRING,
    Item_Outlet_Sales DOUBLE
'''
df = spark.read.format('csv')\
    .schema(ddl)\
    .option('header', True)\
    .load('file:/Workspace/Users/naveenreddu89@gmail.com/DataBricks_Naveen/BigMart_Sales.csv')

# %% [markdown]
# # **Spark SQL**

# %% [markdown]
# #### **CreateTempView**
# - it will create temp view on dataframe and once the session is finished they automatically got deleted

# %%
df.createTempView('myView')

# %% [markdown]
# - Now we can run sql
# - either by changing the Python -> SQL in code cell

# %%
# %sql
Select * from myView

# %% [markdown]
# ### **To get or write data from this sql statement**

# %%
df_sql = spark.sql('SELECT * FROM myView  WHERE Item_Weight < 10')

# %%
display(df_sql)
